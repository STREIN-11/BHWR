# %% [markdown]
# # Image To Sequence Bangla Handwritten Word Recognition

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pickle
import nltk
from pathlib import Path
from collections import Counter
from PIL import Image
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
os.system('pip install -U git+https://github.com/albumentations-team/albumentations')
os.system('pip install -U git+https://github.com/tensorflow/tensorflow')
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
import albumentations as albu
from tensorflow.keras.applications import *

# %%
input = tf.keras.Input(shape=(100,), dtype='int32', name='input')
x = tf.keras.layers.Embedding(
    output_dim=512, input_dim=10000, input_length=100)(input)
x = tf.keras.layers.LSTM(32)(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
output = tf.keras.layers.Dense(1, activation='sigmoid', name='output')(x)
model = tf.keras.Model(inputs=[input], outputs=[output])
dot_img_file = 'IMG_20240104_223208.jpg'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### Importing database (Image)

# %%
seven_zip_path = r'"C:/Program Files/7-Zip/7z.exe"'

data_path = 'converted.zip'

os.system(f'"{seven_zip_path}" x "{data_path}" -o"BanglaWriting_words"')
# Out:
# 1

# %%
data_dir = './wordlevel_data'
# os.system(f"unzip -qq /content/wordlevel_data.zip")

# %%
data_dir = r'./wordlevel_data'
dirs = os.listdir(data_dir)

def resize():
    for item in dirs:
        if os.path.isfile(data_dir+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((200,50), Image.ANTIALIAS)
            imResize.save(f + '.jpg', 'JPEG', quality=100)            
resize()

def filter(imgs, lbls):
    ret_imgs = []
    ret_lbls = []
 
    for i, lbl in enumerate(lbls):
        with open(lbl, 'r', encoding='utf-8') as f:
            txt = f.read()
            ignore = False
            
            if len(txt) > 10: 
                ignore = True
                continue
            
            for c in txt:
                id = ord(c)
                ignore = ignore or (ord('a') <= id and id <= ord('z'))
                ignore = ignore or (ord('A') <= id and id <= ord('Z'))
                ignore = ignore or (ord('0') <= id and id <= ord('9'))
                ignore = ignore or (c in ['%', "'", '(', ')', '*', ',', '-', '.', '/', '\\', 'θ', 'π',])
            
            if not ignore:
                ret_imgs.append(imgs[i])
                ret_lbls.append(lbls[i])
 
    return ret_imgs, ret_lbls

# %%
data_dir_path = Path(data_dir)
 
images = sorted(list(map(str, list(data_dir_path.glob("*.jpg")))))
labels = sorted(list(map(str, list(data_dir_path.glob("*.txt")))))
images, labels = filter(images, labels)
 
img_width = 200
img_height = 50
 
print("Number of images found: ", len(images))
print("Number of labels found: ", len(labels))
 
texts = []

for label in labels:
    f = open (label, 'r', encoding='utf-8')
    text = f.read()
    texts.append(text)
    f.close()
 
characters = set(char for txt in texts for char in txt)
print("Characters present: ", characters)
print("Number of unique characters: ", len(characters))
 
max_length = max([len(txt) for txt in texts])
 
print('Max length', max_length)
characters = sorted(list(characters))
print(characters)
# Out:
# Number of images found:  19066
# Number of labels found:  19066
# Characters present:  {'ই', '^', 'ূ', 'প', 'উ', '"', 'য়', 'গ', '৭', 'আ', 'ড', 'ৎ', '[', 'ঁ', 'ৌ', '৯', 'ং', 'ঋ', 'ড়', 'ি', '১', '৩', 'ঢ়', '০', 'ভ', 'স', 'ঐ', '৪', '২', 'ৈ', 'য', 'ট', 'ম', '=', 'ফ', 'ও', 'ধ', '?', 'ী', 'ঞ', 'ৃ', 'ে', 'ঈ', 'র', 'ষ', 'খ', 'ু', 'ো', 'ল', 'জ', ';', '!', 'ঠ', 'অ', 'এ', '।', '+', 'ছ', 'া', '|', 'ঔ', 'ত', '্', 'থ', 'ঃ', 'ঙ', 'ঘ', 'ন', 'ব', '৫', 'শ', 'দ', '৮', 'হ', 'ঝ', 'চ', '৬', 'ণ', 'ক', 'ঢ'}
# Number of unique characters:  80
# Max length 10
# ['!', '"', '+', ';', '=', '?', '[', '^', '|', '।', 'ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯']

# %%
print(labels[:10])
# Out:
# ['wordlevel_data\\0_21_0_001.txt', 'wordlevel_data\\0_21_0_002.txt', 'wordlevel_data\\0_21_0_003.txt', 'wordlevel_data\\0_21_0_004.txt', 'wordlevel_data\\0_21_0_005.txt', 'wordlevel_data\\0_21_0_006.txt', 'wordlevel_data\\0_21_0_007.txt', 'wordlevel_data\\0_21_0_008.txt', 'wordlevel_data\\0_21_0_009.txt', 'wordlevel_data\\0_21_0_010.txt']

# %%
char_to_num = layers.experimental.preprocessing.StringLookup(
    vocabulary=characters, num_oov_indices=0, #mask_token=" "
)
 
num_to_char = layers.experimental.preprocessing.StringLookup(
    vocabulary=char_to_num.get_vocabulary(), num_oov_indices=1, invert=True,
    oov_token=""
)
 
x_train, x_valid, y_train, y_valid = train_test_split(np.array(images), 
                                                      np.array(texts),
                                                      random_state=42,
                                                      test_size=0.30)
 
x_valid, x_test, y_valid, y_test = train_test_split(x_valid, 
                                                    y_valid,
                                                    random_state=42,
                                                    test_size=0.50)

# %%
print(x_train[:10])
print(y_train[:10])

print(len(x_train))
print(len(x_valid))
print(len(x_test))
# Out:
# ['wordlevel_data\\96_22_0_046.jpg' 'wordlevel_data\\24_25_0_149.jpg'
#  'wordlevel_data\\76_15_0_057.jpg' 'wordlevel_data\\87_15_0_001.jpg'
#  'wordlevel_data\\144_17_0_044.jpg' 'wordlevel_data\\164_16_1_006.jpg'
#  'wordlevel_data\\22_23_0_026.jpg' 'wordlevel_data\\167_16_0_098.jpg'
#  'wordlevel_data\\18_22_0_043.jpg' 'wordlevel_data\\37_23_0_005.jpg']
# ['সোনার' 'না' 'করল' 'আমাদের' 'প্রয়োজনীয়' 'মূল' '২৯' 'ভারতে' 'না'
#  'কিয়ামতের']
# 13346
# 2860
# 2860

# %%
def strong_aug(img_shape, p=0.6, color_augment=False):
    # horizontal
    hh = int(img_shape[0]*0.8)
    hw = int(img_shape[1]*0.08)
    vh = int(img_shape[0]*0.04)
    vw = int(img_shape[1]*0.8)
    return albu.Compose([
        albu.OneOf([
            albu.Cutout(num_holes=4, max_h_size=vh, max_w_size=vw),
            albu.Cutout(num_holes=4, max_h_size=hh, max_w_size=hw),
        ], p=0.3),
        albu.OneOf([
            albu.IAAAdditiveGaussianNoise(),
            albu.GaussNoise(),
        ], p=0.6),

        albu.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.2, 
                              rotate_limit=20, p=0.4),

        albu.OneOf([
            albu.OpticalDistortion(p=0.4),
            albu.GridDistortion(p=0.4),
            albu.IAAPiecewiseAffine(p=0.2),
        ], p=0.5),
    ], p=p)

# %%
def adjust_unicode(character, offset):
    unicode_value = ord(character)
    adjusted_value = unicode_value + offset
    adjusted_character = chr(adjusted_value)
    return adjusted_character

# %%
class DataGen(tf.keras.utils.Sequence):
    def __init__(self, X_dirs, y_labels, augment, batch_size=16,
                 output_shape = (50, 200, 3), p=0.6):
        
        self.img_height     = output_shape[0]
        self.img_width      = output_shape[1]
        self.channels       = output_shape[2]
        self.augment        = augment
        self.batch_size     = batch_size
        self.indexes        = np.arange(y_labels.shape[0])
 
        self.augmentation   = strong_aug((self.img_width, self.img_height, 
                                          self.channels), p=p)
 
        self.x_dirs         = X_dirs
        self.y_labels       = y_labels
 
        self.on_epoch_end()

    def __len__(self):
        return int(self.y_labels.shape[0] // self.batch_size)
 
    def on_epoch_end(self):
        np.random.shuffle(self.indexes)
 
    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        imgs = tf.map_fn(lambda id: tf.transpose(tf.image.resize(tf.io.decode_png(tf.io.read_file(self.x_dirs[id]), 
                                                     channels=1), 
                                                    [self.img_height, self.img_width]), perm=[1, 0, 2]), 
                         indexes, dtype=tf.float32)
        
        imgs = keras.backend.repeat_elements(x=imgs, rep=self.channels, axis=-1)
        imgs = (imgs.numpy()).astype(np.uint8)
        
        labels = char_to_num(tf.strings.unicode_split(self.y_labels[indexes], input_encoding="UTF-8")).to_tensor()
 
        if self.augment:
            return {"image": tf.keras.applications.imagenet_utils.preprocess_input(self.aug(imgs)), "txt": labels}
        return {"image": tf.keras.applications.imagenet_utils.preprocess_input(imgs), "txt": labels}
 
    def read_file(self, fileID):
        img = tf.io.read_file(self.x_dirs[fileID])
        img = tf.io.decode_png(img, channels=1)
        return img
 
    def aug(self, imgs):
        for i, image in enumerate(imgs):
           imgs[i] = self.augmentation(image=image)['image']
 
        return imgs

# %%
text = "আইঈ"
encoded_text = text.encode('utf-8')
print(encoded_text)
decoded_text = encoded_text.decode('utf-8')
print(decoded_text)
# Out:
# b'\xe0\xa6\x86\xe0\xa6\x87\xe0\xa6\x88'
# আইঈ

# %%
import unicodedata

# %%
prop = fm.FontProperties(fname='kalpurush.ttf')
_, ax = plt.subplots(4, 4, figsize=(16, 8))
for data in DataGen(x_train, y_train, True, p=1):
    img, texts = data["image"], data["txt"]
    print(img.shape, texts.shape)
    print(texts)
    for i in range(16):
        txt = tf.strings.reduce_join(num_to_char(texts[i])).numpy().decode("UTF-8")
        ax[i // 4, i % 4].imshow(img[i, :, :, 0].T, cmap="gray")
        ax[i // 4, i % 4].set_title(f"*{txt}*\n{texts[i]}", fontproperties=prop)
        ax[i // 4, i % 4].axis("off")
    break
 
plt.show()
# Out:
# (16, 200, 50, 3) (16, 10)
# tf.Tensor(
# [[45 56 23 65 49 56 69 55 49  0]
#  [14 50 63 23 61  0  0  0  0  0]
#  [14 50 65 50 55 54  0  0  0  0]
#  [19 15  0  0  0  0  0  0  0  0]
#  [53 59 38 65 49 61 49  0  0  0]
#  [23 49 61  0  0  0  0  0  0  0]
#  [48 55 38 65 49 55  0  0  0  0]
#  [24 58 50 61  0  0  0  0  0  0]
#  [54 50 63  0  0  0  0  0  0  0]
#  [54 45 61  0  0  0  0  0  0  0]
#  [23 63 42 63  0  0  0  0  0  0]
#  [25 55 42  0  0  0  0  0  0  0]
#  [43 55 34 55 42 63  0  0  0  0]
#  [ 9  0  0  0  0  0  0  0  0  0]
#  [45 55 11 50 55  0  0  0  0  0]
#  [45 55 11 50 55 40 61 51 61 49]], shape=(16, 10), dtype=int64)

# %%
test_models = ['VGG16', 'VGG19', 'Xception', 'ResNet50', 'ResNet101', 
               'ResNet152', 'ResNet50V2', 'ResNet101V2', 'ResNet152V2', 
               'InceptionV3', 'InceptionResNetV2', 'MobileNet', 'MobileNetV2',
               'DenseNet121', 'DenseNet169', 'DenseNet201']
 
def CustomNetwork(model_name, layer_name=None, 
                  input_shape=(img_width, img_height, 3),
                  add_activation=False):
    
    tf.keras.backend.clear_session()
    inp = layers.Input(input_shape)
    model_str = model_name + "(input_tensor=inp, include_top=False, weights='imagenet')"
    base_model = eval(model_str)
 
    if layer_name == None:
        return base_model
    
    out = base_model.get_layer(layer_name).output
    if add_activation:
        out = layers.ReLU()(out)
 
    return keras.models.Model(inp, out, name=f"{model_name}")
 
 
baseline_name = "DenseNet121"
layer_name = {
    "MobileNet": "conv_pw_5_relu",
    "DenseNet121": "pool3_conv",
    "Xception": "block4_sepconv2",
    "NASNetMobile":"activation_71",
}
 
baseline = CustomNetwork(baseline_name, layer_name[baseline_name], 
                         add_activation=False)
baseline.summary()
# Out:
# Model: "DenseNet121"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 200, 50, 3)]         0         []
#
#  zero_padding2d (ZeroPaddin  (None, 206, 56, 3)           0         ['input_1[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 100, 25, 64)          9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 100, 25, 64)          256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 100, 25, 64)          0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 102, 27, 64)          0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 50, 13, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 50, 13, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 50, 13, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 50, 13, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 50, 13, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 50, 13, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 50, 13, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 50, 13, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 50, 13, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 50, 13, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 50, 13, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 50, 13, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 50, 13, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 50, 13, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 50, 13, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 50, 13, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 50, 13, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 50, 13, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 50, 13, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 50, 13, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 50, 13, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 50, 13, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 50, 13, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 50, 13, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 50, 13, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 50, 13, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 50, 13, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 50, 13, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 50, 13, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 50, 13, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 50, 13, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 50, 13, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 50, 13, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 50, 13, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 25, 6, 128)           0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 25, 6, 128)           512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 25, 6, 128)           16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 25, 6, 160)           0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 25, 6, 160)           640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 25, 6, 160)           0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 25, 6, 128)           20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 25, 6, 192)           0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 25, 6, 192)           768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 25, 6, 192)           0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 25, 6, 128)           24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 25, 6, 224)           0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 25, 6, 224)           896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 25, 6, 224)           0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 25, 6, 128)           28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 25, 6, 256)           0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 25, 6, 256)           1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 25, 6, 256)           0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 25, 6, 128)           32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 25, 6, 288)           0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 25, 6, 288)           1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 25, 6, 288)           0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 25, 6, 128)           36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 25, 6, 320)           0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 25, 6, 320)           1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 25, 6, 320)           0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 25, 6, 128)           40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 25, 6, 352)           0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 25, 6, 352)           1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 25, 6, 352)           0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 25, 6, 128)           45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 25, 6, 384)           0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 25, 6, 384)           1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 25, 6, 384)           0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 25, 6, 128)           49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 25, 6, 128)           512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 25, 6, 128)           0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 25, 6, 32)            36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 25, 6, 416)           0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 25, 6, 416)           1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 25, 6, 416)           0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 25, 6, 128)           53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 25, 6, 128)           512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 25, 6, 128)           0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 25, 6, 32)            36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 25, 6, 448)           0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 25, 6, 448)           1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 25, 6, 448)           0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 25, 6, 128)           57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 25, 6, 128)           512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 25, 6, 128)           0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 25, 6, 32)            36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 25, 6, 480)           0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 25, 6, 480)           1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 25, 6, 480)           0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 25, 6, 128)           61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 25, 6, 128)           512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 25, 6, 128)           0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 25, 6, 32)            36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 25, 6, 512)           0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 25, 6, 512)           2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 25, 6, 512)           0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 25, 6, 256)           131072    ['pool3_relu[0][0]']
#
# ==================================================================================================
# Total params: 1444928 (5.51 MB)
# Trainable params: 1429632 (5.45 MB)
# Non-trainable params: 15296 (59.75 KB)
# __________________________________________________________________________________________________

# %%
train_dataset = DataGen(x_train, y_train, augment=True, p=0.65)
validation_dataset = DataGen(x_valid, y_valid, augment=False)
test_dataset = DataGen(x_test, y_test, augment=False)

# %%
class CTCLayer(layers.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = keras.backend.ctc_batch_cost
 
    def call(self, y_true, y_pred):
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")
 
        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")
 
        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)
 
        return y_pred
 
def build_model(baseline_name, rnn="LSTM"):
    if rnn not in ["LSTM", "GRU"]:
        raise ValueError("INVALID RNN TYPE")

    input_img = layers.Input(
        shape=(img_width, img_height, 3), name="image", dtype="float32"
    )
 
    base = CustomNetwork(baseline_name, layer_name[baseline_name], 
                         add_activation=False)
    x = base(input_img)
    
    print('pass 3', x.shape)
    _, w, h, c = x.shape
    x = layers.Reshape(target_shape=(w, h*c), name="reshape")(x)
 
    texts = layers.Input(name="txt", shape=(None,), dtype="float32")

    print("Bidirectional layer input shape", x.shape)

    if rnn == "LSTM":
        x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.1,
                                          name="LSTM1"), name="BD1")(x)
        x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.1,
                                          name="LSTM2"), name="BD2")(x)
    else:
        x = layers.Bidirectional(layers.GRU(128, return_sequences=True, dropout=0.1,
                                          name="GRU1"))(x)
        x = layers.Bidirectional(layers.GRU(128, return_sequences=True, dropout=0.1,
                                          name="GRU2"))(x)
 
    x = layers.Dense(len(char_to_num.get_vocabulary())+1, 
                     activation="softmax", name="dense2",
                     use_bias=True)(x)
 
    output = CTCLayer(name="ctc_loss")(texts, x)
 
    model = keras.models.Model(
        inputs=[input_img, texts], outputs=output, name=f"ocr_{base.name}_{rnn}",
        #inputs=base.input, outputs=output, name="ocr_model_v1"
    )
    opt = keras.optimizers.Adam()
    model.compile(optimizer=opt)
    return model
 
model = build_model("DenseNet121", "LSTM")
model.summary()
# Out:
# pass 3 (None, 25, 6, 256)
# Bidirectional layer input shape (None, 25, 1536)
# Model: "ocr_DenseNet121_LSTM"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image (InputLayer)          [(None, 200, 50, 3)]         0         []
#
#  DenseNet121 (Functional)    (None, 25, 6, 256)           1444928   ['image[0][0]']
#
#  reshape (Reshape)           (None, 25, 1536)             0         ['DenseNet121[0][0]']
#
#  BD1 (Bidirectional)         (None, 25, 128)              819712    ['reshape[0][0]']
#
#  BD2 (Bidirectional)         (None, 25, 256)              263168    ['BD1[0][0]']
#
#  txt (InputLayer)            [(None, None)]               0         []
#
#  dense2 (Dense)              (None, 25, 81)               20817     ['BD2[0][0]']
#
#  ctc_loss (CTCLayer)         (None, 25, 81)               0         ['txt[0][0]',
#                                                                      'dense2[0][0]']
#
# ==================================================================================================
# Total params: 2548625 (9.72 MB)
# Trainable params: 2533329 (9.66 MB)
# Non-trainable params: 15296 (59.75 KB)
# __________________________________________________________________________________________________

# %%
#build_model("NASNetMobile", "GRU").summary()

# %%
# plot_model(model, to_file='model_plot.png', show_shapes=True, 
#            show_layer_names=True, expand_nested=False)

# %%
history = model.fit(
        DataGen(x_train, y_train, True, p=1),
        epochs=1,
    )
# Out:
# 834/834 [==============================] - 1201s 1s/step - loss: 18.5589

# %%
def load_submodel(model_dir, lmodel):
    cnt = 0
    temp_model = tf.keras.models.load_model(model_dir)
    for i, layer in enumerate(temp_model.layers):
        try:
            lmodel.get_layer(layer.name).set_weights(layer.get_weights())
            print('Layer:', layer.name)
            cnt += 1
        except:
            continue
    print(f"{cnt} layer weights loaded")

# %%
class SaveLog(tf.keras.callbacks.Callback):
    def __init__(self, save_path='./log/', 
                 save_on_epoch=-1, monitor='loss', mode='auto', 
                 load_prev=False, patience=5, save_best_model=True,
                 restore_best_weights=True,
                 verbose=True):
        
        self.os  = __import__('os')
        self.pkl = __import__('pickle')
        self.np = __import__('numpy')
        self.tf = __import__('tensorflow')
        self.tf.get_logger().setLevel('ERROR')
        super(SaveLog, self).__init__() 
        
        self.save_on_epoch = save_on_epoch
        if save_on_epoch < -1:
            raise ValueError("Invalid 'save_on_epoch' value." 
                             " Should be greater than -1.")

        self.monitor = monitor
        self.save_dir = None
        self.log_dir = None
        self.save_best_model = save_best_model
        self.patience = patience
        self.patience_kept = 0
        self.logs = {}
        self.load_prev = load_prev
        self.verbose = verbose
        self.restore_best_weights = restore_best_weights
        self.save_path = save_path
        
        if mode == 'min':
            self.monitor_op = self.np.less
            self.metric_val = self.np.inf
            self.mode = 'min'
        elif mode == 'max':
            self.monitor_op = self.np.greater
            self.metric_val = -self.np.inf
            self.mode = 'max'
        else:
            if 'acc' in self.monitor:
                self.monitor_op = self.np.greater
                self.metric_val = -self.np.inf
                self.mode = 'max'
            else:
                self.monitor_op = self.np.less
                self.metric_val = self.np.inf
                self.mode = 'min'


    def _save_model(self, best=False):
        sdir = self.best_dir if best else self.save_dir
        if best:
            self.model.save_weights(sdir)
        else:
            self.model.save(sdir, overwrite=True)
        #if self.verbose: 
        print(f'{"Best m" if best else "M"}odel saved on {sdir}')  


    def _load_model(self):
        try:
            self.model.load_weights(self.save_dir)
            if self.verbose: print('Weights loaded')
            return
        except:
            pass
        try:
            cnt = 0
            temp_model = self.tf.keras.models.load_model(self.save_dir)
            for i, layer in enumerate(temp_model.layers):
                try:
                    self.model.get_layer(layer.name).set_weights(layer.get_weights())
                    cnt += 1
                except:
                    continue
            if self.verbose: print(f"{cnt} layer weights loaded")
        except:
            pass


    def _save_logs(self, epoch):
        with open(self.log_dir, 'wb') as f:
            self.pkl.dump(self.logs, f)
        if self.verbose: print(f'Logs saved on epoch {epoch+1}')


    def _load_logs(self):
        try:
            with open(self.log_dir, 'rb') as f:
                log = self.pkl.load(f)
            if self.mode == 'max':
                self.metric_val = max(log[self.monitor])
            else:
                self.metric_val = min(log[self.monitor])
            if self.verbose: print(f'Logs loaded, best {self.monitor}: {self.metric_val:.5f}')
            return log
        except:
            return {}


    def _saver(self, epoch, logs):
        log_val = logs[self.monitor]
        if self.save_on_epoch == 0:
            self._save_logs(epoch)
            self._save_model()

            if self.save_best_model and self.monitor_op(log_val, self.metric_val):
                self.metric_val = log_val
                self._save_model(best=True)

        elif self.save_on_epoch == -1:
            if self.monitor_op(log_val, self.metric_val):
                self.metric_val = log_val
                if self.verbose: print('Minimum loss found')
                self._save_logs(epoch)
                if self.save_best_model:
                    self._save_model(best=True)
        else:
            if epoch % self.save_on_epoch == 0:
                self._save_logs(epoch)
                self._save_model()
            
            if self.save_best_model and self.monitor_op(log_val, self.metric_val):
                self.metric_val = log_val
                self._save_model(best=True)
                

    def on_train_begin(self, logs=None):
        self.save_dir = self.os.path.join(self.save_path, self.model.name, '')
        self.best_dir = self.os.path.join(self.save_dir, 'best_weight.h5')
        self.log_dir = self.os.path.join(self.save_dir, 'train_log.pkl')
         
        if self.verbose: print('SavePath', self.save_dir)
        if not self.os.path.exists(self.save_dir):
            self.os.makedirs(self.save_dir)
            if self.verbose: print('New directory created')
        elif self.load_prev:
            self._load_model()
            self.logs = self._load_logs() or {}


    def on_epoch_end(self, epoch, logs=None):
        for key, val in logs.items():
            if key not in self.logs:
                self.logs[key] = []
            self.logs[key].append(val)
        
        if self.patience != None:
            if self.monitor_op(logs[self.monitor], self.metric_val):
                self.patience_kept = 0
            else:
                self.patience_kept += 1
            if self.patience_kept > self.patience:
                self.model.stop_training = True
                if self.verbose: print("Stopping training")
                if self.restore_best_weights:
                    if self.verbose: print("Restoring best weights")
                    self.model.load_weights(self.best_dir)
        
        self._saver(epoch, logs)

epochs = 1000
early_stopping_patience = 10

# %%
dirs = ['./OCR_v2/ocr_DenseNet121_GRU', './OCR_v2/ocr_NASNetMobile_GRU',
        './OCR_v2/ocr_NASNetMobile_LSTM',]

def get_flops(model_h5_path):
    tf.compat.v1.reset_default_graph()
    tf.keras.backend.clear_session()
    session = tf.compat.v1.Session()
    graph = tf.compat.v1.get_default_graph()

    with graph.as_default():
        with session.as_default():
            model = tf.keras.models.load_model(model_h5_path)
            run_meta = tf.compat.v1.RunMetadata()
            opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        
            # We use the Keras session graph in the call to the profiler.
            flops = tf.compat.v1.profiler.profile(graph=graph,
                                                  run_meta=run_meta, cmd='op', options=opts)
        
            return flops.total_float_ops


for d in dirs[1:]:
    print(d.split('/')[-1], ":", get_flops(d))
# Out:
# WARNING:tensorflow:From c:\Users\PRITOM\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:883: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:Output {0} missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to ctc_loss.
# WARNING:tensorflow:From c:\Users\PRITOM\anaconda3\Lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:140: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# ocr_NASNetMobile_GRU : 2489705
# WARNING:tensorflow:Output {0} missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to ctc_loss.
# ocr_NASNetMobile_LSTM : 1957225

# %%
# Train the model
for baseline in list(layer_name.keys())[3:]:
    model = build_model(baseline, "GRU")
 
    logger = SaveLog(save_path='./OCR_v2', monitor='val_loss', 
                    save_on_epoch=5, patience=early_stopping_patience, 
                    verbose=False, load_prev=True)
    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=epochs,
        verbose=0,
        callbacks=[logger],
        max_queue_size=20,
    )
 
    #========================================
    model = build_model(baseline, "LSTM")
 
    logger = SaveLog(save_path='./OCR_v2', monitor='val_loss', 
                    save_on_epoch=5, patience=early_stopping_patience, 
                    verbose=False, load_prev=True)
    
    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=epochs,
        verbose=0,
        callbacks=[logger],
        max_queue_size=20,
    )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 [==============================] - 13s 1us/step
# pass 3 (None, 25, 6, 88)
# Bidirectional layer input shape (None, 25, 528)
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_GRU\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# Model saved on ./OCR_v2\ocr_NASNetMobile_GRU\
# pass 3 (None, 25, 6, 88)
# Bidirectional layer input shape (None, 25, 528)
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Best model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\best_weight.h5
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\
# Model saved on ./OCR_v2\ocr_NASNetMobile_LSTM\

# %%
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_length
    ]
    output_text = []
    for res in results:
        res = tf.strings.reduce_join(num_to_char(res)).numpy().decode("utf-8")
        output_text.append(res)
    return output_text

# %%
dirs = ['./OCR_v2/ocr_NASNetMobile_LSTM',
        './OCR_v2/ocr_NASNetMobile_GRU',
        './OCR_v2/ocr_DenseNet121_GRU',]
 
for ldir in dirs[:2]:
    tmodel = tf.keras.models.load_model(ldir)
    data_order = ["Train", "Validation", "Test"]
    tmodel.load_weights(os.path.join(ldir, 'best_weight.h5'))
 
    print()
    print(ldir.split('/')[-1])
    print('='*25)
    print()
 
    prediction_model = keras.models.Model(
        tmodel.get_layer(name="image").input, tmodel.get_layer(name="dense2").output
    )
 
    ret = tmodel.evaluate(train_dataset, verbose=0)
    print('Train loss:', ret)
    ret = tmodel.evaluate(validation_dataset, verbose=0)
    print('Validation loss:', ret)
    ret = tmodel.evaluate(test_dataset, verbose=0)
    print('Test: loss', ret)
 
    for i, (xxx, yyy) in enumerate([(x_train, y_train), 
                                (x_valid, y_valid), 
                                (x_test, y_test)]):
        TOT = xxx.shape[0]
        TOTC, WAC, CE = 0, 0, 0
 
        print(f"Calculating on {data_order[i]} data")
 
        for batch in DataGen(xxx, yyy, augment=False, batch_size=16):
            batch_images = batch["image"]
            batch_texts = batch["txt"]
        
            preds = prediction_model.predict(batch_images)
            pred_texts = decode_batch_predictions(preds)
        
            orig_texts = []
            for txt in batch_texts:
                txt = tf.strings.reduce_join(num_to_char(txt)).numpy().decode("utf-8")
                orig_texts.append(txt)
        
            for i in range(min(len(pred_texts), 16)):
                if pred_texts[i] == orig_texts[i]:
                    WAC += 1
                CE += nltk.edit_distance(pred_texts[i], orig_texts[i], 
                                        transpositions=True)
                TOTC += len(orig_texts[i])
                
 
        print(f"Total: {TOT}, Accurate: {WAC}, WER: {(TOT-WAC)/TOT},"
           f"CER: {CE/TOTC}")

        print(f"CER: {CE/TOTC},"
              f"WER: {(TOT-WAC)/TOT}")
# Out:
# ocr_NASNetMobile_LSTM
# =========================
#
# Train loss: 3.3083856105804443
# Validation loss: 4.376464366912842
# Test: loss 4.644872665405273
# Calculating on Train data
# c:\Users\PRITOM\anaconda3\Lib\site-packages\albumentations\augmentations\dropout\cutout.py:49: FutureWarning: Cutout has been deprecated. Please use CoarseDropout
#   warnings.warn(
# c:\Users\PRITOM\anaconda3\Lib\site-packages\albumentations\imgaug\transforms.py:261: FutureWarning: IAAAdditiveGaussianNoise is deprecated. Please use GaussNoise instead
#   warnings.warn("IAAAdditiveGaussianNoise is deprecated. Please use GaussNoise instead", FutureWarning)
# c:\Users\PRITOM\anaconda3\Lib\site-packages\albumentations\imgaug\transforms.py:299: FutureWarning: This IAAPiecewiseAffine is deprecated. Please use PiecewiseAffine instead
#   warnings.warn("This IAAPiecewiseAffine is deprecated. Please use PiecewiseAffine instead", FutureWarning)
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 0s 363ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 1s 515ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 321ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 202ms/step
# Total: 13346, Accurate: 12280, WER: 0.07987411958639293,CER: 0.022634152788791963
# CER: 0.022634152788791963,WER: 0.07987411958639293
# Calculating on Validation data
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 384ms/step
# ...
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 348ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 195ms/step
# Total: 2860, Accurate: 1703, WER: 0.40454545454545454,CER: 0.18311291963377416
# CER: 0.18311291963377416,WER: 0.40454545454545454
# Calculating on Test data
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# Total: 2860, Accurate: 1745, WER: 0.38986013986013984,CER: 0.1831041257367387
# CER: 0.1831041257367387,WER: 0.38986013986013984

# %%
prediction_model = keras.models.Model(
    tmodel.get_layer(name="image").input, tmodel.get_layer(name="dense2").output
)
 
prop = fm.FontProperties(fname='./kalpurush.ttf')
 
for batch in DataGen(x_test, y_test, augment=False):
    batch_images = batch["image"]
    batch_texts = batch["txt"]
 
    print(len(batch_images), "images")
    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
 
    orig_texts = []
    for txt in batch_texts:
        txt = tf.strings.reduce_join(num_to_char(txt)).numpy().decode("utf-8")
        orig_texts.append(txt)
    _, ax = plt.subplots(4, 4, figsize=(16, 7))
 
    for i in range(min(len(pred_texts), 16)):
        img = ((batch_images[i, :, :, 0]))
        img = img.T
        ttext = tf.strings.reduce_join(num_to_char(batch_texts[i])).numpy().decode("utf-8")
        title = f"True:{ttext}\nPrediction:{pred_texts[i]}\n{np.argmax(preds[i], axis=-1)[:10]}"
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title, fontproperties=prop, color="black")
        ax[i // 4, i % 4].axis("off")
    break
 
plt.tight_layout()
plt.show()
# Out:
# 16 images
# 1/1 [==============================] - 5s 5s/step

# %%
print(len(char_to_num.get_vocabulary()))
print(char_to_num.get_vocabulary())
print(char_to_num.get_config())
print(char_to_num.get_weights())
# Out:
# 80
# ['!', '"', '+', ';', '=', '?', '[', '^', '|', '।', 'ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯']
# {'name': 'string_lookup', 'trainable': True, 'dtype': 'int64', 'invert': False, 'max_tokens': None, 'num_oov_indices': 0, 'oov_token': '[UNK]', 'mask_token': None, 'output_mode': 'int', 'sparse': False, 'pad_to_max_tokens': False, 'idf_weights': None, 'vocabulary': ListWrapper(['!', '"', '+', ';', '=', '?', '[', '^', '|', '।', 'ঁ', 'ং', 'ঃ', 'অ', 'আ', 'ই', 'ঈ', 'উ', 'ঋ', 'এ', 'ঐ', 'ও', 'ঔ', 'ক', 'খ', 'গ', 'ঘ', 'ঙ', 'চ', 'ছ', 'জ', 'ঝ', 'ঞ', 'ট', 'ঠ', 'ড', 'ঢ', 'ণ', 'ত', 'থ', 'দ', 'ধ', 'ন', 'প', 'ফ', 'ব', 'ভ', 'ম', 'য', 'র', 'ল', 'শ', 'ষ', 'স', 'হ', 'া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', '্', 'ৎ', 'ড়', 'ঢ়', 'য়', '০', '১', '২', '৩', '৪', '৫', '৬', '৭', '৮', '৯']), 'vocabulary_size': 80, 'encoding': 'utf-8'}
# []

# %%
prediction_model = keras.models.Model(
    tmodel.get_layer(name="image").input, tmodel.get_layer(name="dense2").output
)
 
prop = fm.FontProperties(fname='./kalpurush.ttf')

def transform_character(char):
    key_map = {
        'ল':'ব','অ':'আ', 'আ':'ই', 'ই':'ঈ', 'ঈ':'উ', 'উ':'ঊ', 'ঊ':'ঋ', 'ঋ':'এ', 'এ':'ঐ', 'ঐ':'ও','ও':'ঔ',
        'ঔ':'ক', 'ক': 'খ', 'খ': 'গ', 'গ': 'ঘ', 'ঘ': 'ঙ', 'ঙ' : 'চ', 'চ':'ছ', 'ছ':'জ', 'জ':'ঝ',
        'ঝ':'ঞ', 'ঞ':'ট', 'ট':'ঠ', 'ঠ':'ড', 'ড':'ঢ', 'ঢ':'ণ', 'ণ':'ত', 'ত':'থ', 'থ':'দ', 'দ':'ধ',
        'ধ':'ন', 'ন':'প', 'প':'ফ', 'ফ':'ল', 'ব':'ভ', 'ভ':'ম',
        'ম':'য', 'য':'র', 'র':'ফ', 'ল':'শ', 'শ':'ষ', 'ষ':'স', 'স':'হ', 'হ':'া',
        'ড়':'ঢ়', 'ঢ়':'য়', 'য়':'ৎ', 'ৎ':'ং', 'ং':'ঃ', 'ঃ':'ঁ', 'ৃ':'ে', 'া':'ি',
        'ী':'ু', 'ৌ':'র', 'ঁ':'অ', 'ফ':'ল', 'ৈ':'ো', 'ো':'া',
    }

    return key_map.get(char, char)

prediction_model = keras.models.Model(
    tmodel.get_layer(name="image").input, tmodel.get_layer(name="dense2").output
)

for batch in DataGen(x_test, y_test, augment=False):
    batch_images = batch["image"]
    batch_texts = batch["txt"]

    print(len(batch_images), "images")
    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)

    orig_texts = []
    for txt in batch_texts:
        txt = tf.strings.reduce_join(num_to_char(txt)).numpy().decode("utf-8")
        orig_texts.append(txt)

    _, ax = plt.subplots(4, 4, figsize=(16, 7))

    for i in range(min(len(pred_texts), 16)):
        img = ((batch_images[i, :, :, 0]))
        img = img.T

        ttext_with_unicode = ''.join([transform_character(char) for char in orig_texts[i]])
        
        ttext = tf.strings.reduce_join(num_to_char(batch_texts[i])).numpy().decode("utf-8")
        pred_text_with_unicode = ''.join([transform_character(char) for char in pred_texts[i]])
        
        title = f"True:{ttext_with_unicode}\nPrediction:{pred_text_with_unicode}\n{np.argmax(preds[i], axis=-1)[:10]}"
        
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title, fontproperties=prop, color="gray")
        ax[i // 4, i % 4].axis("off")

    break

plt.tight_layout()
plt.show()
# Out:
# 16 images
# 1/1 [==============================] - 7s 7s/step
